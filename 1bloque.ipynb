# %%
# !pip install onedrivedownloader
from onedrivedownloader import download

url = 'https://universidadfv-my.sharepoint.com/:u:/g/personal/alberto_desantos_ufv_es/EVwGsj7cAV5EvjJPWcqJ1lUBPhP5mKEkv-6fzmAM4jJSkw?e=pjOhYH'

download(url = url, filename = 'archivo.zip', unzip=True, force_download=True, clean=True)
# Out:
# Requirement already satisfied: onedrivedownloader in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# 100%|██████████| 34.5M/34.5M [00:03<00:00, 10.4MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 200/200 [00:00<00:00, 95119.72it/s]
# ''

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization,Conv2DTranspose,Activation,concatenate,Input
from tensorflow.keras import Sequential,Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
def conv_block(input,filters):
    x = Conv2D(filters,3,padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters,3,padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def encoder_block(input,filters):

    x = conv_block(input,filters)
    p = MaxPooling2D((2,2))(x)
    return x,p

def decoder_block(input,skip,filters):

    x = Conv2DTranspose(filters,2,strides=2,padding="same")(input)
    x = concatenate([x,skip])
    x = conv_block(x,filters)
    return x

# %%
def build_model_1_layer():
    # Entrada del modelo
    input = Input(shape=(512, 512, 3))

    # Encoder con 1 capa
    x1, p1 = encoder_block(input, 64)   # Primera y única capa del encoder

    # Bottleneck (parte intermedia)
    a1 = conv_block(p1, 128)

    # Decoder con 1 capa
    d1 = decoder_block(a1, x1, 64)      # Primera y única capa del decoder

    # Capa de salida
    output = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d1)

    # Definir el modelo
    model = Model(input, output)
    return model

# %%
def load_data(path,img_size):
    images = []
    masks = []
    for img_files,mask_files in zip(os.listdir(path+"/image"),os.listdir(path+"/mask")):
        img_path = os.path.join(path+"/image",img_files)
        mask_path = os.path.join(path+"/mask",mask_files)

        img = load_img(img_path,target_size=img_size)
        mask = load_img(mask_path,target_size=img_size,color_mode="grayscale")

        img = img_to_array(img)/255.0
        mask = img_to_array(mask)/255.0

        images.append(img)
        masks.append(mask)
    return np.array(images),np.array(masks)

# %%
def augment_image(image, mask):

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, mask

# %%
x_train,y_train = load_data("/content/Data/train",img_size=(512,512))
x_test,y_test = load_data("/content/Data/test",img_size=(512,512))
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((80, 512, 512, 3), (80, 512, 512, 1), (20, 512, 512, 3), (20, 512, 512, 1))

# %%
def tf_dataset(x,y,batch_size=8):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=8)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = tf_dataset(x_train,y_train,batch_size=8)
test_dataset = tf_dataset(x_test,y_test,batch_size=8)

# %%
model = build_model_1_layer()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min',
                               verbose=1, restore_best_weights=True)

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    batch_size=8,
                    validation_data=test_dataset,
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.7764 - loss: 0.4756
# Epoch 1: val_loss improved from inf to 0.60377, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 936ms/step - accuracy: 0.7813 - loss: 0.4698 - val_accuracy: 0.8770 - val_loss: 0.6038
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.8738 - loss: 0.3119
# Epoch 2: val_loss improved from 0.60377 to 0.53997, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 781ms/step - accuracy: 0.8740 - loss: 0.3107 - val_accuracy: 0.8770 - val_loss: 0.5400
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.8738 - loss: 0.2825
# Epoch 3: val_loss improved from 0.53997 to 0.49496, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 858ms/step - accuracy: 0.8740 - loss: 0.2819 - val_accuracy: 0.8770 - val_loss: 0.4950
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.8738 - loss: 0.2757
# Epoch 4: val_loss improved from 0.49496 to 0.45684, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 804ms/step - accuracy: 0.8741 - loss: 0.2751 - val_accuracy: 0.8770 - val_loss: 0.4568
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.8742 - loss: 0.2705
# Epoch 5: val_loss improved from 0.45684 to 0.42238, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 770ms/step - accuracy: 0.8744 - loss: 0.2701 - val_accuracy: 0.8770 - val_loss: 0.4224
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 677ms/step - accuracy: 0.8726 - loss: 0.2767
# Epoch 6: val_loss improved from 0.42238 to 0.40651, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 759ms/step - accuracy: 0.8730 - loss: 0.2759 - val_accuracy: 0.8770 - val_loss: 0.4065
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.8737 - loss: 0.2712
# Epoch 7: val_loss improved from 0.40651 to 0.36742, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 761ms/step - accuracy: 0.8740 - loss: 0.2704 - val_accuracy: 0.8770 - val_loss: 0.3674
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.8735 - loss: 0.2637
# Epoch 8: val_loss did not improve from 0.36742
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 751ms/step - accuracy: 0.8738 - loss: 0.2634 - val_accuracy: 0.8770 - val_loss: 0.3885
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - accuracy: 0.8740 - loss: 0.2671
# Epoch 9: val_loss improved from 0.36742 to 0.36141, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 758ms/step - accuracy: 0.8742 - loss: 0.2668 - val_accuracy: 0.8770 - val_loss: 0.3614
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.8746 - loss: 0.2669
# Epoch 10: val_loss improved from 0.36141 to 0.35226, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 766ms/step - accuracy: 0.8748 - loss: 0.2665 - val_accuracy: 0.8770 - val_loss: 0.3523
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.8738 - loss: 0.2682
# Epoch 11: val_loss did not improve from 0.35226
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 757ms/step - accuracy: 0.8741 - loss: 0.2677 - val_accuracy: 0.8770 - val_loss: 0.3616
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.8729 - loss: 0.2668
# Epoch 12: val_loss improved from 0.35226 to 0.34620, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 791ms/step - accuracy: 0.8733 - loss: 0.2663 - val_accuracy: 0.8770 - val_loss: 0.3462
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.
val_loss did not improve from 0.23395
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 754ms/step - accuracy: 0.8737 - loss: 0.2708 - val_accuracy: 0.8770 - val_loss: 0.2524
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.8740 - loss: 0.2610
# Epoch 70: val_loss did not improve from 0.23395
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 761ms/step - accuracy: 0.8743 - loss: 0.2605 - val_accuracy: 0.8770 - val_loss: 0.2572
# Epoch 70: early stopping
# Restoring model weights from the end of the best epoch: 55.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def calculate_metrics(y_true, y_pred, threshold=0.5):
    # Ensure binary targets
    y_true_binary = (y_true > threshold).astype(np.int32)
    y_pred_binary = (y_pred > threshold).astype(np.int32)

    # IoU
    intersection = np.sum(y_true_binary * y_pred_binary)
    union = np.sum(y_true_binary) + np.sum(y_pred_binary) - intersection
    iou = intersection / (union + 1e-6)

    # F1 Score
    y_true_flat = y_true_binary.flatten()
    y_pred_flat = y_pred_binary.flatten()
    f1 = f1_score(y_true_flat, y_pred_flat)

    # Dice Loss
    dice = dice_loss(y_true_binary, y_pred_binary)

    return iou, f1, dice.numpy()

# Analyze all images in x_test
metrics = []

for index in range(len(x_test)):
    # Get image and its corresponding mask
    image = x_test[index]
    mask = y_test[index]

    # Predict mask using the trained model
    predicted_mask = model.predict(image[np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    # Calculate metrics
    iou, f1, dice_loss_value = calculate_metrics(mask, predicted_mask)
    metrics.append((iou, f1, dice_loss_value))

# Convert metrics to numpy array for easier calculations
metrics = np.array(metrics)

# Print metrics statistics
print("Metrics Summary:")
print(f"Average IoU: {np.mean(metrics[:, 0]):.4f}")
print(f"IoU Standard Deviation: {np.std(metrics[:, 0]):.4f}")
print(f"Average F1 Score: {np.mean(metrics[:, 1]):.4f}")
print(f"F1 Score Standard Deviation: {np.std(metrics[:, 1]):.4f}")
print(f"Average Dice Loss: {np.mean(metrics[:, 2]):.4f}")
print(f"Dice Loss Standard Deviation: {np.std(metrics[:, 2]):.4f}")

# Visualization of first three images with masks
plt.figure(figsize=(20, 15))

for i in range(3):
    # Original image
    plt.subplot(3, 3, i*3+1)
    plt.imshow(x_test[i])
    plt.title(f"Original Image {i+1}")
    plt.axis('off')

    # Real mask
    plt.subplot(3, 3, i*3+2)
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    plt.title(f"Real Mask {i+1}")
    plt.axis('off')

    # Predicted mask
    predicted_mask = model.predict(x_test[i][np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    plt.subplot(3, 3, i*3+3)
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.title(f"Predicted Mask {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Metrics Summary:
# Average IoU: 0.5263
# IoU Standard Deviation: 0.1041
# Average F1 Score: 0.6829
# F1 Score Standard Deviation: 0.0998
# Average Dice Loss: 0.3171
# Dice Loss Standard Deviation: 0.0998
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %% [markdown]
# Graficas

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para los gráficos
labels = ['1 Capa', '2 Capas', '3 Capas', '4 Capas (Original)', '5 Capas']
iou_means = [0.5263, 0.5764, 0.4984, 0.3362, 0.0846]
iou_std = [0.1041, 0.0473, 0.0525, 0.0377, 0.0665]

f1_means = [0.6829, 0.7301, 0.6635, 0.5020, 0.1495]
f1_std = [0.0998, 0.0390, 0.0483, 0.0425, 0.1071]

dice_means = [0.3171, 0.2699, 0.3365, 0.4980, 0.8505]
dice_std = [0.0998, 0.0390, 0.0483, 0.0425, 0.1071]

# Gráfico de barras para Average IoU
plt.figure(figsize=(10, 6))
plt.bar(labels, iou_means, yerr=iou_std, capsize=5, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('Número de Capas')
plt.ylabel('Average IoU')
plt.title('Comparación de Average IoU para Diferentes Números de Capas')
plt.show()

# Gráfico de barras para Average F1 Score
plt.figure(figsize=(10, 6))
plt.bar(labels, f1_means, yerr=f1_std, capsize=5, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('Número de Capas')
plt.ylabel('Average F1 Score')
plt.title('Comparación de Average F1 Score para Diferentes Números de Capas')
plt.show()

# Gráfico de barras para Average Dice Loss
plt.figure(figsize=(10, 6))
plt.bar(labels, dice_means, yerr=dice_std, capsize=5, color=['blue', 'green', 'orange', 'red', 'purple'])
plt.xlabel('Número de Capas')
plt.ylabel('Average Dice Loss')
plt.title('Comparación de Average Dice Loss para Diferentes Números de Capas')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para los gráficos
labels = ['1 Capa', '2 Capas', '3 Capas', '4 Capas (Original)', '5 Capas']
iou_means = [0.5263, 0.5764, 0.4984, 0.3362, 0.0846]
iou_std = [0.1041, 0.0473, 0.0525, 0.0377, 0.0665]

f1_means = [0.6829, 0.7301, 0.6635, 0.5020, 0.1495]
f1_std = [0.0998, 0.0390, 0.0483, 0.0425, 0.1071]

dice_means = [0.3171, 0.2699, 0.3365, 0.4980, 0.8505]
dice_std = [0.0998, 0.0390, 0.0483, 0.0425, 0.1071]

fig, axs = plt.subplots(1, 3, figsize=(24, 6))

# Gráfico de barras para Average IoU
axs[0].bar(labels, iou_means, yerr=iou_std, capsize=5, color=['blue', 'green', 'orange', 'red', 'purple'])
axs[0].set_xlabel('Número de Capas')
axs[0].set_ylabel('Average IoU')
axs[0].set_title('Comparación de Average IoU para Diferentes Números de Capas')

# Gráfico de barras para Average F1 Score
axs[1].bar(labels, f1_means, yerr=f1_std, capsize=5, color=['blue', 'green', 'orange', 'red', 'purple'])
axs[1].set_xlabel('Número de Capas')
axs[1].set_ylabel('Average F1 Score')
axs[1].set_title('Comparación de Average F1 Score para Diferentes Números de Capas')

# Gráfico de barras para Average Dice Loss
axs[2].bar(labels, dice_means, yerr=dice_std, capsize=5, color=['blue', 'green', 'orange', 'red', 'purple'])
axs[2].set_xlabel('Número de Capas')
axs[2].set_ylabel('Average Dice Loss')
axs[2].set_title('Comparación de Average Dice Loss para Diferentes Números de Capas')

plt.tight_layout()
plt.show()
