# %%
# !pip install onedrivedownloader
from onedrivedownloader import download

url = 'https://universidadfv-my.sharepoint.com/:u:/g/personal/alberto_desantos_ufv_es/EVwGsj7cAV5EvjJPWcqJ1lUBPhP5mKEkv-6fzmAM4jJSkw?e=pjOhYH'

download(url = url, filename = 'archivo.zip', unzip=True, force_download=True, clean=True)
# Out:
# Collecting onedrivedownloader
#   Downloading onedrivedownloader-1.1.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# Downloading onedrivedownloader-1.1.3-py3-none-any.whl (5.1 kB)
# Installing collected packages: onedrivedownloader
# Successfully installed onedrivedownloader-1.1.3
# 100%|██████████| 34.5M/34.5M [00:03<00:00, 9.01MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 200/200 [00:00<00:00, 317.65it/s]
# ''

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization,Conv2DTranspose,Activation,concatenate,Input
from tensorflow.keras import Sequential,Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
def conv_block(input,filters):
    x = Conv2D(filters,3,padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters,3,padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def encoder_block(input,filters):

    x = conv_block(input,filters)
    p = MaxPooling2D((2,2))(x)
    return x,p

def decoder_block(input,skip,filters):

    x = Conv2DTranspose(filters,2,strides=2,padding="same")(input)
    x = concatenate([x,skip])
    x = conv_block(x,filters)
    return x

# %%
def build_model_3_layers():
    input = Input(shape=(512, 512, 3))

    # Encoder con 3 capas
    x1, p1 = encoder_block(input, 64)
    x2, p2 = encoder_block(p1, 128)
    x3, p3 = encoder_block(p2, 256)

    # Bottleneck
    a1 = conv_block(p3, 512)

    # Decoder con 3 capas
    d1 = decoder_block(a1, x3, 256)
    d2 = decoder_block(d1, x2, 128)
    d3 = decoder_block(d2, x1, 64)

    output = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d3)
    model = Model(input, output)
    return model

# %%
def load_data(path,img_size):
    images = []
    masks = []
    for img_files,mask_files in zip(os.listdir(path+"/image"),os.listdir(path+"/mask")):
        img_path = os.path.join(path+"/image",img_files)
        mask_path = os.path.join(path+"/mask",mask_files)

        img = load_img(img_path,target_size=img_size)
        mask = load_img(mask_path,target_size=img_size,color_mode="grayscale")

        img = img_to_array(img)/255.0
        mask = img_to_array(mask)/255.0

        images.append(img)
        masks.append(mask)
    return np.array(images),np.array(masks)

# %%
def augment_image(image, mask):

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, mask

# %%
x_train,y_train = load_data("/content/Data/train",img_size=(512,512))
x_test,y_test = load_data("/content/Data/test",img_size=(512,512))
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((80, 512, 512, 3), (80, 512, 512, 1), (20, 512, 512, 3), (20, 512, 512, 1))

# %%
def tf_dataset(x,y,batch_size=8):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=8)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = tf_dataset(x_train,y_train,batch_size=8)
test_dataset = tf_dataset(x_test,y_test,batch_size=8)

# %%
model = build_model_3_layers()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min',
                               verbose=1, restore_best_weights=True)

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    batch_size=8,
                    validation_data=test_dataset,
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6300 - loss: 0.6180
# Epoch 1: val_loss improved from inf to 2.68386, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.6424 - loss: 0.6052 - val_accuracy: 0.0746 - val_loss: 2.6839
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8738 - loss: 0.3003
# Epoch 2: val_loss did not improve from 2.68386
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8740 - loss: 0.2995 - val_accuracy: 0.1175 - val_loss: 10.2676
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.2872
# Epoch 3: val_loss improved from 2.68386 to 2.08035, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8739 - loss: 0.2866 - val_accuracy: 0.3241 - val_loss: 2.0803
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.2792
# Epoch 4: val_loss improved from 2.08035 to 1.02629, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8739 - loss: 0.2787 - val_accuracy: 0.4416 - val_loss: 1.0263
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8738 - loss: 0.2743
# Epoch 5: val_loss did not improve from 1.02629
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8740 - loss: 0.2739 - val_accuracy: 0.0718 - val_loss: 2.5133
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8728 - loss: 0.2748
# Epoch 6: val_loss improved from 1.02629 to 0.82675, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8731 - loss: 0.2743 - val_accuracy: 0.3270 - val_loss: 0.8268
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8746 - loss: 0.2711
# Epoch 7: val_loss improved from 0.82675 to 0.48737, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8748 - loss: 0.2708 - val_accuracy: 0.8545 - val_loss: 0.4874
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8731 - loss: 0.2718
# Epoch 8: val_loss improved from 0.48737 to 0.43813, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8734 - loss: 0.2712 - val_accuracy: 0.8770 - val_loss: 0.4381
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - loss: 0.2700
# Epoch 9: val_loss did not improve from 0.43813
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8744 - loss: 0.2696 - val_accuracy: 0.8770 - val_loss: 0.4493
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8730 - loss: 0.2694
# Epoch 10: val_loss improved from 0.43813 to 0.41834, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8734 - loss: 0.2689 - val_accuracy: 0.8770 - val_loss: 0.4183
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8743 - loss: 0.2665
# Epoch 11: val_loss improved from 0.41834 to 0.39830, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8745 - loss: 0.2660 - val_accuracy: 0.8770 - val_loss: 0.3983
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8732 - loss: 0.2635
# Epoch 12: val_loss improved from 0.39830 to 0.36316, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8735 - loss: 0.2633 - val_accuracy: 0.8770 - val_loss: 0.3632
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8742 - loss: 0.2680
# Epoch 13: val_loss improved from 0.36316 to 0.35865, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8744 - loss: 0.2675 - val_accuracy: 0.8770 - val_loss: 0.3587
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8728 - loss: 0.2676
# Epoch 14: val_loss did not improve from 0.35865
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8732 - loss: 0.2669 - val_accuracy: 0.8770 - val_loss: 0.3646
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8738 - loss: 0.2564
# Epoch 15: val_loss improved from 0.35865 to 0.35171, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8741 - loss: 0.2560 - val_accuracy: 0.8770 - val_loss: 0.3517
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8726 - loss: 0.2642
# Epoch 16: val_loss improved from 0.35171 to 0.34736, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8729 - loss: 0.2637 - val_accuracy: 0.8770 - val_loss: 0.3474
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.2611
# Epoch 17: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8739 - loss: 0.2611 - val_accuracy: 0.8770 - val_loss: 0.3494
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8727 - loss: 0.2704
# Epoch 18: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8730 - loss: 0.2698 - val_accuracy: 0.8770 - val_loss: 0.3718
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8725 - loss: 0.2682
# Epoch 19: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8729 - loss: 0.2676 - val_accuracy: 0.8770 - val_loss: 0.4026
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8727 - loss: 0.2621
# Epoch 20: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8730 - loss: 0.2618 - val_accuracy: 0.8770 - val_loss: 0.3948
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8734 - loss: 0.2554
# Epoch 21: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8736 - loss: 0.2553 - val_accuracy: 0.8770 - val_loss: 0.3678
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - loss: 0.2543
# Epoch 22: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8744 - loss: 0.2543 - val_accuracy: 0.8770 - val_loss: 0.3788
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8731 - loss: 0.2644
# Epoch 23: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8734 - loss: 0.2638 - val_accuracy: 0.8770 - val_loss: 0.3741
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8740 - loss: 0.2605
# Epoch 24: val_loss did not improve from 0.34736
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8742 - loss: 0.2603 - val_accuracy: 0.8770 - val_loss: 0.3656
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8725 - loss: 0.2675
# Epoch 25: val_loss improved from 0.34736 to 0.32099, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8729 - loss: 0.2670 - val_accuracy: 0.8770 - val_loss: 0.3210
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8748 - loss: 0.2572
# Epoch 26: val_loss did not improve from 0.32099
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8749 - loss: 0.2571 - val_accuracy: 0.8770 - val_loss: 0.3581
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8735 - loss: 0.2664
# Epoch 27: val_loss did not improve from 0.32099
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8738 - loss: 0.2659 - val_accuracy: 0.8770 - val_loss: 0.3718
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8733 - loss: 0.2656
# Epoch 28: val_loss improved from 0.32099 to 0.31773, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8736 - loss: 0.2649 - val_accuracy: 0.8770 - val_loss: 0.3177
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8725 - loss: 0.2699
# Epoch 29: val_loss did not improve from 0.31773
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8728 - loss: 0.2691 - val_accuracy: 0.8770 - val_loss: 0.3399
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8744 - loss: 0.2635
# Epoch 30: val_loss did not improve from 0.31773
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8746 - loss: 0.2630 - val_accuracy: 0.8770 - val_loss: 0.3389
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8750 - loss: 0.2599
# Epoch 31: val_loss improved from 0.31773 to 0.28281, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8752 - loss: 0.2597 - val_accuracy: 0.8770 - val_loss: 0.2828
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8745 - loss: 0.2668
# Epoch 32: val_loss did not improve from 0.28281
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8747 - loss: 0.2661 - val_accuracy: 0.8770 - val_loss: 0.3013
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - loss: 0.2551
# Epoch 33: val_loss did not improve from 0.28281
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8744 - loss: 0.2548 - val_accuracy: 0.8770 - val_loss: 0.3389
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8729 - loss: 0.2597
# Epoch 34: val_loss improved from 0.28281 to 0.27853, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8732 - loss: 0.2596 - val_accuracy: 0.8770 - val_loss: 0.2785
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8737 - loss: 0.2596
# Epoch 35: val_loss did not improve from 0.27853
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8739 - loss: 0.2591 - val_accuracy: 0.8770 - val_loss: 0.2797
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8731 - loss: 0.2679
# Epoch 36: val_loss did not improve from 0.27853
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8734 - loss: 0.2673 - val_accuracy: 0.8770 - val_loss: 0.2865
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8734 - loss: 0.2620
# Epoch 37: val_loss did not improve from 0.27853
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8737 - loss: 0.2614 - val_accuracy: 0.8770 - val_loss: 0.2973
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - loss: 0.2607
# Epoch 38: val_loss improved from 0.27853 to 0.27734, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8743 - loss: 0.2599 - val_accuracy: 0.8770 - val_loss: 0.2773
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8743 - loss: 0.2652
# Epoch 39: val_loss did not improve from 0.27734
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8745 - loss: 0.2649 - val_accuracy: 0.8770 - val_loss: 0.2983
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8744 - loss: 0.2610
# Epoch 40: val_loss improved from 0.27734 to 0.27632, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8746 - loss: 0.2602 - val_accuracy: 0.8770 - val_loss: 0.2763
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8729 - loss: 0.2609
# Epoch 41: val_loss did not improve from 0.27632
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8732 - loss: 0.2606 - val_accuracy: 0.8770 - val_loss: 0.2768
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8742 - loss: 0.2664
# Epoch 42: val_loss did not improve from 0.27632
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8744 - loss: 0.2658 - val_accuracy: 0.8770 - val_loss: 0.2914
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8732 - loss: 0.2637
# Epoch 43: val_loss improved from 0.27632 to 0.27079, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8735 - loss: 0.2631 - val_accuracy: 0.8770 - val_loss: 0.2708
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8747 - loss: 0.2627
# Epoch 44: val_loss did not improve from 0.27079
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8749 - loss: 0.2622 - val_accuracy: 0.8770 - val_loss: 0.2751
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.2547
# Epoch 45: val_loss did not improve from 0.27079
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8739 - loss: 0.2543 - val_accuracy: 0.8770 - val_loss: 0.2729
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8745 - loss: 0.2602
# Epoch 46: val_loss improved from 0.27079 to 0.26260, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8747 - loss: 0.2598 - val_accuracy: 0.8770 - val_loss: 0.2626
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8740 - loss: 0.2630
# Epoch 47: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8742 - loss: 0.2625 - val_accuracy: 0.8770 - val_loss: 0.2654
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8731 - loss: 0.2629
# Epoch 48: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8734 - loss: 0.2623 - val_accuracy: 0.8770 - val_loss: 0.2702
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8747 - loss: 0.2567
# Epoch 49: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8749 - loss: 0.2562 - val_accuracy: 0.8770 - val_loss: 0.2651
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8742 - loss: 0.2556
# Epoch 50: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8745 - loss: 0.2554 - val_accuracy: 0.8770 - val_loss: 0.2726
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8737 - loss: 0.2557
# Epoch 51: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8740 - loss: 0.2553 - val_accuracy: 0.8770 - val_loss: 0.2633
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8736 - loss: 0.2580
# Epoch 52: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8739 - loss: 0.2578 - val_accuracy: 0.8770 - val_loss: 0.2811
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8734 - loss: 0.2564
# Epoch 53: val_loss did not improve from 0.26260
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8738 - loss: 0.2557 - val_accuracy: 0.8770 - val_loss: 0.2676
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8729 - loss: 0.2628
# Epoch 54: val_loss improved from 0.26260 to 0.26231, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8732 - loss: 0.2623 - val_accuracy: 0.8770 - val_loss: 0.2623
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8745 - loss: 0.2608
# Epoch 55: val_loss did not improve from 0.26231
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8747 - loss: 0.2607 - val_accuracy: 0.8770 - val_loss: 0.2643
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8733 - loss: 0.2687
# Epoch 56: val_loss did not improve from 0.26231
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8736 - loss: 0.2678 - val_accuracy: 0.8770 - val_loss: 0.2708
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8740 - loss: 0.2591
# Epoch 57: val_loss did not improve from 0.26231
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8743 - loss: 0.2587 - val_accuracy: 0.8770 - val_loss: 0.2751
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8748 - loss: 0.2650
# Epoch 58: val_loss improved from 0.26231 to 0.26077, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8749 - loss: 0.2647 - val_accuracy: 0.8770 - val_loss: 0.2608
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8737 - loss: 0.2567
# Epoch 59: val_loss improved from 0.26077 to 0.25759, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8740 - loss: 0.2567 - val_accuracy: 0.8770 - val_loss: 0.2576
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8733 - loss: 0.2617
# Epoch 60: val_loss did not improve from 0.25759
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8736 - loss: 0.2610 - val_accuracy: 0.8770 - val_loss: 0.2617
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8744 - loss: 0.2573
# Epoch 61: val_loss did not improve from 0.25759
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8746 - loss: 0.2571 - val_accuracy: 0.8770 - val_loss: 0.2716
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8738 - loss: 0.2675
# Epoch 62: val_loss did not improve from 0.25759
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8741 - loss: 0.2668 - val_accuracy: 0.8770 - val_loss: 0.2690
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8729 - loss: 0.2657
# Epoch 63: val_loss improved from 0.25759 to 0.25311, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8733 - loss: 0.2646 - val_accuracy: 0.8770 - val_loss: 0.2531
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8747 - loss: 0.2596
# Epoch 64: val_loss did not improve from 0.25311
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8749 - loss: 0.2593 - val_accuracy: 0.8770 - val_loss: 0.2552
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8739 - loss: 0.2543
# Epoch 65: val_loss improved from 0.25311 to 0.25246, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8742 - loss: 0.2543 - val_accuracy: 0.8770 - val_loss: 0.2525
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8745 - loss: 0.2580
# Epoch 66: val_loss improved from 0.25246 to 0.24953, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8747 - loss: 0.2576 - val_accuracy: 0.8770 - val_loss: 0.2495
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - loss: 0.2557
# Epoch 67: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8743 - loss: 0.2556 - val_accuracy: 0.8770 - val_loss: 0.2558
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8732 - loss: 0.2584
# Epoch 68: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8736 - loss: 0.2579 - val_accuracy: 0.8770 - val_loss: 0.2551
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8743 - loss: 0.2598
# Epoch 69: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8745 - loss: 0.2595 - val_accuracy: 0.8770 - val_loss: 0.2520
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8734 - loss: 0.2568
# Epoch 70: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8737 - loss: 0.2566 - val_accuracy: 0.8770 - val_loss: 0.2676
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8735 - loss: 0.2544
# Epoch 71: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8738 - loss: 0.2541 - val_accuracy: 0.8770 - val_loss: 0.2499
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8742 - loss: 0.2605
# Epoch 72: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8744 - loss: 0.2599 - val_accuracy: 0.8770 - val_loss: 0.2725
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8735 - loss: 0.2600
# Epoch 73: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8738 - loss: 0.2597 - val_accuracy: 0.8770 - val_loss: 0.2573
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8741 - loss: 0.2629
# Epoch 74: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8743 - loss: 0.2625 - val_accuracy: 0.8770 - val_loss: 0.2546
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8737 - loss: 0.2555
# Epoch 75: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8740 - loss: 0.2550 - val_accuracy: 0.8770 - val_loss: 0.2719
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8740 - loss: 0.2644
# Epoch 76: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8742 - loss: 0.2632 - val_accuracy: 0.8770 - val_loss: 0.2664
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8743 - loss: 0.2574
# Epoch 77: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8745 - loss: 0.2573 - val_accuracy: 0.8770 - val_loss: 0.2625
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8737 - loss: 0.2541
# Epoch 78: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8740 - loss: 0.2539 - val_accuracy: 0.8770 - val_loss: 0.2657
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8735 - loss: 0.2573
# Epoch 79: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8738 - loss: 0.2572 - val_accuracy: 0.8770 - val_loss: 0.2553
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8732 - loss: 0.2690
# Epoch 80: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8735 - loss: 0.2682 - val_accuracy: 0.8770 - val_loss: 0.2773
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8737 - loss: 0.2618
# Epoch 81: val_loss did not improve from 0.24953
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8740 - loss: 0.2616 - val_accuracy: 0.8770 - val_loss: 0.2563
# Epoch 81: early stopping
# Restoring model weights from the end of the best epoch: 66.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def calculate_metrics(y_true, y_pred, threshold=0.5):
    # Ensure binary targets
    y_true_binary = (y_true > threshold).astype(np.int32)
    y_pred_binary = (y_pred > threshold).astype(np.int32)

    # IoU
    intersection = np.sum(y_true_binary * y_pred_binary)
    union = np.sum(y_true_binary) + np.sum(y_pred_binary) - intersection
    iou = intersection / (union + 1e-6)

    # F1 Score
    y_true_flat = y_true_binary.flatten()
    y_pred_flat = y_pred_binary.flatten()
    f1 = f1_score(y_true_flat, y_pred_flat)

    # Dice Loss
    dice = dice_loss(y_true_binary, y_pred_binary)

    return iou, f1, dice.numpy()

# Analyze all images in x_test
metrics = []

for index in range(len(x_test)):
    # Get image and its corresponding mask
    image = x_test[index]
    mask = y_test[index]

    # Predict mask using the trained model
    predicted_mask = model.predict(image[np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    # Calculate metrics
    iou, f1, dice_loss_value = calculate_metrics(mask, predicted_mask)
    metrics.append((iou, f1, dice_loss_value))

# Convert metrics to numpy array for easier calculations
metrics = np.array(metrics)

# Print metrics statistics
print("Metrics Summary:")
print(f"Average IoU: {np.mean(metrics[:, 0]):.4f}")
print(f"IoU Standard Deviation: {np.std(metrics[:, 0]):.4f}")
print(f"Average F1 Score: {np.mean(metrics[:, 1]):.4f}")
print(f"F1 Score Standard Deviation: {np.std(metrics[:, 1]):.4f}")
print(f"Average Dice Loss: {np.mean(metrics[:, 2]):.4f}")
print(f"Dice Loss Standard Deviation: {np.std(metrics[:, 2]):.4f}")

# Visualization of first three images with masks
plt.figure(figsize=(20, 15))

for i in range(3):
    # Original image
    plt.subplot(3, 3, i*3+1)
    plt.imshow(x_test[i])
    plt.title(f"Original Image {i+1}")
    plt.axis('off')

    # Real mask
    plt.subplot(3, 3, i*3+2)
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    plt.title(f"Real Mask {i+1}")
    plt.axis('off')

    # Predicted mask
    predicted_mask = model.predict(x_test[i][np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    plt.subplot(3, 3, i*3+3)
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.title(f"Predicted Mask {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Metrics Summary:
# Average IoU: 0.4984
# IoU Standard Deviation: 0.0525
# Average F1 Score: 0.6635
# F1 Score Standard Deviation: 0.0483
# Average Dice Loss: 0.3365
# Dice Loss Standard Deviation: 0.0483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
