# %%
# !pip install onedrivedownloader
from onedrivedownloader import download

url = 'https://universidadfv-my.sharepoint.com/:u:/g/personal/alberto_desantos_ufv_es/EVwGsj7cAV5EvjJPWcqJ1lUBPhP5mKEkv-6fzmAM4jJSkw?e=pjOhYH'

download(url = url, filename = 'archivo.zip', unzip=True, force_download=True, clean=True)
# Out:
# Requirement already satisfied: onedrivedownloader in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# 100%|██████████| 34.5M/34.5M [00:03<00:00, 10.3MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 200/200 [00:00<00:00, 125427.75it/s]
# ''

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization,Conv2DTranspose,Activation,concatenate,Input
from tensorflow.keras import Sequential,Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
def conv_block(input,filters):
    x = Conv2D(filters,3,padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters,3,padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def encoder_block(input,filters):

    x = conv_block(input,filters)
    p = MaxPooling2D((2,2))(x)
    return x,p

def decoder_block(input,skip,filters):

    x = Conv2DTranspose(filters,2,strides=2,padding="same")(input)
    x = concatenate([x,skip])
    x = conv_block(x,filters)
    return x

# %%
def build_model():
    input = Input(shape=(512,512,3))

    x1,p1 = encoder_block(input,64)
    x2,p2 = encoder_block(p1,128)
    x3,p3 = encoder_block(p2,256)
    x4,p4 = encoder_block(p3,512)

    a1 = conv_block(p4,1024)

    d1 = decoder_block(a1,x4,512)
    d2 = decoder_block(d1,x3,256)
    d3 = decoder_block(d2,x2,128)
    d4 = decoder_block(d3,x1,64)

    output = Conv2D(1,(1,1),padding="same",activation="sigmoid")(d4)
    model = Model(input,output)
    return model

# %%
def load_data(path,img_size):
    images = []
    masks = []
    for img_files,mask_files in zip(os.listdir(path+"/image"),os.listdir(path+"/mask")):
        img_path = os.path.join(path+"/image",img_files)
        mask_path = os.path.join(path+"/mask",mask_files)

        img = load_img(img_path,target_size=img_size)
        mask = load_img(mask_path,target_size=img_size,color_mode="grayscale")

        img = img_to_array(img)/255.0
        mask = img_to_array(mask)/255.0

        images.append(img)
        masks.append(mask)
    return np.array(images),np.array(masks)

# %%
def augment_image(image, mask):

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, mask

# %%
x_train,y_train = load_data("/content/Data/train",img_size=(512,512))
x_test,y_test = load_data("/content/Data/test",img_size=(512,512))
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((80, 512, 512, 3), (80, 512, 512, 1), (20, 512, 512, 3), (20, 512, 512, 1))

# %%
def tf_dataset(x,y,batch_size=4):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=8)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = tf_dataset(x_train,y_train,batch_size=4)
test_dataset = tf_dataset(x_test,y_test,batch_size=4)

# %%
model = build_model()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min',
                               verbose=1, restore_best_weights=True)

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    batch_size=4,
                    validation_data=test_dataset,
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.7780 - loss: 0.4541
# Epoch 1: val_loss improved from inf to 17.32609, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.7811 - loss: 0.4494 - val_accuracy: 0.0606 - val_loss: 17.3261
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.8802 - loss: 0.2717
# Epoch 2: val_loss did not improve from 17.32609
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 959ms/step - accuracy: 0.8800 - loss: 0.2718 - val_accuracy: 0.0601 - val_loss: 578.9797
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.8814 - loss: 0.2633
# Epoch 3: val_loss improved from 17.32609 to 1.51240, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8812 - loss: 0.2636 - val_accuracy: 0.1556 - val_loss: 1.5124
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - accuracy: 0.8792 - loss: 0.2605
# Epoch 4: val_loss improved from 1.51240 to 0.91632, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.8790 - loss: 0.2608 - val_accuracy: 0.6907 - val_loss: 0.9163
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.8803 - loss: 0.2614
# Epoch 5: val_loss did not improve from 0.91632
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 956ms/step - accuracy: 0.8802 - loss: 0.2617 - val_accuracy: 0.7300 - val_loss: 4.1759
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.8803 - loss: 0.2617
# Epoch 6: val_loss improved from 0.91632 to 0.71178, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.8801 - loss: 0.2619 - val_accuracy: 0.8397 - val_loss: 0.7118
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.8815 - loss: 0.2552
# Epoch 7: val_loss improved from 0.71178 to 0.31288, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8812 - loss: 0.2557 - val_accuracy: 0.8770 - val_loss: 0.3129
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.8794 - loss: 0.2558
# Epoch 8: val_loss did not improve from 0.31288
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.8792 - loss: 0.2560 - val_accuracy: 0.8770 - val_loss: 0.3263
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.8793 - loss: 0.2601
# Epoch 9: val_loss did not improve from 0.31288
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 949ms/step - accuracy: 0.8792 - loss: 0.2603 - val_accuracy: 0.8770 - val_loss: 0.3418
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.8800 - loss: 0.2541
# Epoch 10: val_loss did not improve from 0.31288
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 988ms/step - accuracy: 0.8799 - loss: 0.2543 - val_accuracy: 0.8770 - val_loss: 0.3171
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.8807 - loss: 0.2451
# Epoch 11: val_loss improved from 0.31288 to 0.30900, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.8805 - loss: 0.2455 - val_accuracy: 0.8770 - val_loss: 0.3090
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8783 - loss: 0.2504
# Epoch 12: val_loss improved from 0.30900 to 0.30364, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8781 - loss: 0.2506 - val_accuracy: 0.8770 - val_loss: 0.3036
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.8813 - loss: 0.2546
# Epoch 13: val_loss did not improve from 0.30364
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 955ms/step - accuracy: 0.8811 - loss: 0.2550 - val_accuracy: 0.8770 - val_loss: 0.3067
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 859ms/step - accuracy: 0.8802 - loss: 0.2509
# Epoch 14: val_loss improved from 0.30364 to 0.29605, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8800 - loss: 0.2513 - val_accuracy: 0.8770 - val_loss: 0.2960
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.8804 - loss: 0.2515
# Epoch 15: val_loss improved from 0.29605 to 0.28115, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.8802 - loss: 0.2518 - val_accuracy: 0.8770 - val_loss: 0.2811
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.8798 - loss: 0.2524
# Epoch 16: val_loss did not improve from 0.28115
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 954ms/step - accuracy: 0.8796 - loss: 0.2529 - val_accuracy: 0.8770 - val_loss: 0.2821
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.8797 - loss: 0.2553
# Epoch 17: val_loss did not improve from 0.28115
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 947ms/step - accuracy: 0.8796 - loss: 0.2555 - val_accuracy: 0.8770 - val_loss: 0.2897
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.8811 - loss: 0.2512
# Epoch 18: val_loss improved from 0.28115 to 0.28048, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8809 - loss: 0.2514 - val_accuracy: 0.8770 - val_loss: 0.2805
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.8805 - loss: 0.2610
# Epoch 19: val_loss improved from 0.28048 to 0.27665, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8803 - loss: 0.2614 - val_accuracy: 0.8770 - val_loss: 0.2766
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.8804 - loss: 0.2593
# Epoch 20: val_loss did not improve from 0.27665
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 949ms/step - accuracy: 0.8802 - loss: 0.2596 - val_accuracy: 0.8770 - val_loss: 1.0464
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 873ms/step - accuracy: 0.8797 - loss: 0.2608
# Epoch 21: val_loss did not improve from 0.27665
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 954ms/step - accuracy: 0.8795 - loss: 0.2610 - val_accuracy: 0.8770 - val_loss: 0.6156
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.8807 - loss: 0.2560
# Epoch 22: val_loss did not improve from 0.27665
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 989ms/step - accuracy: 0.8805 - loss: 0.2563 - val_accuracy: 0.8770 - val_loss: 0.3011
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.8802 - loss: 0.2553
# Epoch 23: val_loss did not improve from 0.27665
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 934ms/step - accuracy: 0.8800 - loss: 0.2556 - val_accuracy: 0.8770 - val_loss: 0.2774
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8800 - loss: 0.2513
# Epoch 24: val_loss did not improve from 0.27665
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 940ms/step - accuracy: 0.8798 - loss: 0.2517 - val_accuracy: 0.8770 - val_loss: 0.2913
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.8801 - loss: 0.2525
# Epoch 25: val_loss improved from 0.27665 to 0.26730, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8799 - loss: 0.2526 - val_accuracy: 0.8770 - val_loss: 0.2673
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.8817 - loss: 0.2572
# Epoch 26: val_loss improved from 0.26730 to 0.26419, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8815 - loss: 0.2574 - val_accuracy: 0.8770 - val_loss: 0.2642
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.8802 - loss: 0.2491
# Epoch 27: val_loss improved from 0.26419 to 0.26189, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8800 - loss: 0.2493 - val_accuracy: 0.8770 - val_loss: 0.2619
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - accuracy: 0.8809 - loss: 0.2469
# Epoch 28: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 992ms/step - accuracy: 0.8807 - loss: 0.2473 - val_accuracy: 0.8770 - val_loss: 0.2758
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - accuracy: 0.8797 - loss: 0.2597
# Epoch 29: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8795 - loss: 0.2598 - val_accuracy: 0.8770 - val_loss: 0.2625
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8803 - loss: 0.2503
# Epoch 30: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 996ms/step - accuracy: 0.8802 - loss: 0.2505 - val_accuracy: 0.8770 - val_loss: 0.2687
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.8801 - loss: 0.2542
# Epoch 31: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 931ms/step - accuracy: 0.8799 - loss: 0.2544 - val_accuracy: 0.8770 - val_loss: 0.2975
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - accuracy: 0.8815 - loss: 0.2535
# Epoch 32: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 935ms/step - accuracy: 0.8813 - loss: 0.2536 - val_accuracy: 0.8770 - val_loss: 0.2693
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.8820 - loss: 0.2563
# Epoch 33: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 946ms/step - accuracy: 0.8818 - loss: 0.2566 - val_accuracy: 0.8770 - val_loss: 0.2722
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8807 - loss: 0.2474
# Epoch 34: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 997ms/step - accuracy: 0.8805 - loss: 0.2478 - val_accuracy: 0.8770 - val_loss: 0.2821
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.8813 - loss: 0.2533
# Epoch 35: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 991ms/step - accuracy: 0.8811 - loss: 0.2536 - val_accuracy: 0.8770 - val_loss: 0.2726
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.8796 - loss: 0.2530
# Epoch 36: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 935ms/step - accuracy: 0.8794 - loss: 0.2532 - val_accuracy: 0.8770 - val_loss: 0.2663
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.8811 - loss: 0.2456
# Epoch 37: val_loss did not improve from 0.26189
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 998ms/step - accuracy: 0.8809 - loss: 0.2462 - val_accuracy: 0.8770 - val_loss: 0.2655
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.8811 - loss: 0.2529
# Epoch 38: val_loss improved from 0.26189 to 0.26004, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8809 - loss: 0.2533 - val_accuracy: 0.8770 - val_loss: 0.2600
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 855ms/step - accuracy: 0.8790 - loss: 0.2556
# Epoch 39: val_loss did not improve from 0.26004
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 936ms/step - accuracy: 0.8789 - loss: 0.2557 - val_accuracy: 0.8770 - val_loss: 0.3818
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 880ms/step - accuracy: 0.8796 - loss: 0.2426
# Epoch 40: val_loss did not improve from 0.26004
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.8795 - loss: 0.2431 - val_accuracy: 0.8770 - val_loss: 0.3006
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.8812 - loss: 0.2470
# Epoch 41: val_loss did not improve from 0.26004
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 998ms/step - accuracy: 0.8810 - loss: 0.2473 - val_accuracy: 0.8769 - val_loss: 0.2813
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.8795 - loss: 0.2418
# Epoch 42: val_loss did not improve from 0.26004
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 987ms/step - accuracy: 0.8794 - loss: 0.2422 - val_accuracy: 0.8770 - val_loss: 0.2889
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - accuracy: 0.8805 - loss: 0.2410
# Epoch 43: val_loss did not improve from 0.26004
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 937ms/step - accuracy: 0.8803 - loss: 0.2415 - val_accuracy: 0.8769 - val_loss: 0.2855
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.8822 - loss: 0.2474
# Epoch 44: val_loss did not improve from 0.26004
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 947ms/step - accuracy: 0.8819 - loss: 0.2478 - val_accuracy: 0.8770 - val_loss: 0.2888
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.8809 - loss: 0.2497
# Epoch 45: val_loss improved from 0.26004 to 0.25710, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8807 - loss: 0.2500 - val_accuracy: 0.8770 - val_loss: 0.2571
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.8806 - loss: 0.2493
# Epoch 46: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 935ms/step - accuracy: 0.8804 - loss: 0.2495 - val_accuracy: 0.8762 - val_loss: 0.2714
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 877ms/step - accuracy: 0.8806 - loss: 0.2498
# Epoch 47: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 957ms/step - accuracy: 0.8804 - loss: 0.2499 - val_accuracy: 0.8627 - val_loss: 0.2910
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.8804 - loss: 0.2548
# Epoch 48: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 944ms/step - accuracy: 0.8802 - loss: 0.2550 - val_accuracy: 0.8552 - val_loss: 0.3233
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.8812 - loss: 0.2445
# Epoch 49: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 934ms/step - accuracy: 0.8810 - loss: 0.2449 - val_accuracy: 0.8724 - val_loss: 0.2761
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.8813 - loss: 0.2527
# Epoch 50: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 990ms/step - accuracy: 0.8811 - loss: 0.2529 - val_accuracy: 0.8770 - val_loss: 0.2609
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.8799 - loss: 0.2498
# Epoch 51: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 945ms/step - accuracy: 0.8798 - loss: 0.2501 - val_accuracy: 0.8769 - val_loss: 0.2781
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.8810 - loss: 0.2491
# Epoch 52: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 941ms/step - accuracy: 0.8808 - loss: 0.2494 - val_accuracy: 0.8769 - val_loss: 0.2767
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 859ms/step - accuracy: 0.8796 - loss: 0.2438
# Epoch 53: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 938ms/step - accuracy: 0.8795 - loss: 0.2441 - val_accuracy: 0.8730 - val_loss: 0.2707
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - accuracy: 0.8811 - loss: 0.2343
# Epoch 54: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 936ms/step - accuracy: 0.8809 - loss: 0.2349 - val_accuracy: 0.8770 - val_loss: 0.2662
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.8795 - loss: 0.2373
# Epoch 55: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 996ms/step - accuracy: 0.8793 - loss: 0.2379 - val_accuracy: 0.8747 - val_loss: 0.2762
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 862ms/step - accuracy: 0.8809 - loss: 0.2428
# Epoch 56: val_loss did not improve from 0.25710
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 942ms/step - accuracy: 0.8807 - loss: 0.2433 - val_accuracy: 0.8770 - val_loss: 0.2642
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.8798 - loss: 0.2499
# Epoch 57: val_loss improved from 0.25710 to 0.25662, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8797 - loss: 0.2500 - val_accuracy: 0.8754 - val_loss: 0.2566
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.8811 - loss: 0.2487
# Epoch 58: val_loss improved from 0.25662 to 0.25525, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8809 - loss: 0.2489 - val_accuracy: 0.8770 - val_loss: 0.2552
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.8789 - loss: 0.2479
# Epoch 59: val_loss did not improve from 0.25525
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 956ms/step - accuracy: 0.8788 - loss: 0.2479 - val_accuracy: 0.8768 - val_loss: 0.2580
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.8798 - loss: 0.2437
# Epoch 60: val_loss improved from 0.25525 to 0.24965, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - accuracy: 0.8797 - loss: 0.2440 - val_accuracy: 0.8770 - val_loss: 0.2497
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.8819 - loss: 0.2495
# Epoch 61: val_loss did not improve from 0.24965
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 31s 984ms/step - accuracy: 0.8816 - loss: 0.2496 - val_accuracy: 0.8770 - val_loss: 0.2616
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.8817 - loss: 0.2466
# Epoch 62: val_loss did not improve from 0.24965
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8814 - loss: 0.2472 - val_accuracy: 0.8770 - val_loss: 0.2648
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.8807 - loss: 0.2492
# Epoch 63: val_loss did not improve from 0.24965
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8805 - loss: 0.2495 - val_accuracy: 0.8770 - val_loss: 0.2584
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.8808 - loss: 0.2507
# Epoch 64: val_loss did not improve from 0.24965
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 934ms/step - accuracy: 0.8806 - loss: 0.2509 - val_accuracy: 0.8769 - val_loss: 0.2755
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.8815 - loss: 0.2447
# Epoch 65: val_loss did not improve from 0.24965
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 933ms/step - accuracy: 0.8813 - loss: 0.2450 - val_accuracy: 0.8770 - val_loss: 0.2530
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.8819 - loss: 0.2464
# Epoch 66: val_loss improved from 0.24965 to 0.24565, saving model to best_model.keras
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 3s/step - accuracy: 0.8817 - loss: 0.2468 - val_accuracy: 0.8770 - val_loss: 0.2456
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8805 - loss: 0.2499
# Epoch 67: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 996ms/step - accuracy: 0.8804 - loss: 0.2502 - val_accuracy: 0.8770 - val_loss: 0.2639
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - accuracy: 0.8812 - loss: 0.2439
# Epoch 68: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8809 - loss: 0.2441 - val_accuracy: 0.8770 - val_loss: 0.2804
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8804 - loss: 0.2449
# Epoch 69: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 942ms/step - accuracy: 0.8802 - loss: 0.2453 - val_accuracy: 0.8770 - val_loss: 0.2570
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.8814 - loss: 0.2528
# Epoch 70: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 934ms/step - accuracy: 0.8812 - loss: 0.2530 - val_accuracy: 0.8770 - val_loss: 0.2885
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - accuracy: 0.8806 - loss: 0.2536
# Epoch 71: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 993ms/step - accuracy: 0.8804 - loss: 0.2536 - val_accuracy: 0.8770 - val_loss: 0.2670
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.8804 - loss: 0.2514
# Epoch 72: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8802 - loss: 0.2516 - val_accuracy: 0.8770 - val_loss: 0.2677
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8795 - loss: 0.2477
# Epoch 73: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 941ms/step - accuracy: 0.8794 - loss: 0.2481 - val_accuracy: 0.8770 - val_loss: 0.2634
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.8797 - loss: 0.2493
# Epoch 74: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 936ms/step - accuracy: 0.8796 - loss: 0.2495 - val_accuracy: 0.8770 - val_loss: 0.2566
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 858ms/step - accuracy: 0.8804 - loss: 0.2464
# Epoch 75: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 993ms/step - accuracy: 0.8803 - loss: 0.2469 - val_accuracy: 0.8770 - val_loss: 0.2589
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 862ms/step - accuracy: 0.8790 - loss: 0.2497
# Epoch 76: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 945ms/step - accuracy: 0.8789 - loss: 0.2500 - val_accuracy: 0.8767 - val_loss: 0.2577
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8801 - loss: 0.2482
# Epoch 77: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 940ms/step - accuracy: 0.8799 - loss: 0.2484 - val_accuracy: 0.8767 - val_loss: 0.2638
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.8799 - loss: 0.2477
# Epoch 78: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 20s 939ms/step - accuracy: 0.8797 - loss: 0.2479 - val_accuracy: 0.8770 - val_loss: 0.2633
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.8810 - loss: 0.2404
# Epoch 79: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 941ms/step - accuracy: 0.8808 - loss: 0.2410 - val_accuracy: 0.8770 - val_loss: 0.2494
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 859ms/step - accuracy: 0.8807 - loss: 0.2396
# Epoch 80: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 995ms/step - accuracy: 0.8806 - loss: 0.2400 - val_accuracy: 0.8770 - val_loss: 0.2675
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.8800 - loss: 0.2476
# Epoch 81: val_loss did not improve from 0.24565
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 19s 941ms/step - accuracy: 0.8798 - loss: 0.2478 - val_accuracy: 0.8770 - val_loss: 0.2712
# Epoch 81: early stopping
# Restoring model weights from the end of the best epoch: 66.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def calculate_metrics(y_true, y_pred, threshold=0.5):
    # Ensure binary targets
    y_true_binary = (y_true > threshold).astype(np.int32)
    y_pred_binary = (y_pred > threshold).astype(np.int32)

    # IoU
    intersection = np.sum(y_true_binary * y_pred_binary)
    union = np.sum(y_true_binary) + np.sum(y_pred_binary) - intersection
    iou = intersection / (union + 1e-6)

    # F1 Score
    y_true_flat = y_true_binary.flatten()
    y_pred_flat = y_pred_binary.flatten()
    f1 = f1_score(y_true_flat, y_pred_flat)

    # Dice Loss
    dice = dice_loss(y_true_binary, y_pred_binary)

    return iou, f1, dice.numpy()

# Analyze all images in x_test
metrics = []

for index in range(len(x_test)):
    # Get image and its corresponding mask
    image = x_test[index]
    mask = y_test[index]

    # Predict mask using the trained model
    predicted_mask = model.predict(image[np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    # Calculate metrics
    iou, f1, dice_loss_value = calculate_metrics(mask, predicted_mask)
    metrics.append((iou, f1, dice_loss_value))

# Convert metrics to numpy array for easier calculations
metrics = np.array(metrics)

# Print metrics statistics
print("Metrics Summary:")
print(f"Average IoU: {np.mean(metrics[:, 0]):.4f}")
print(f"IoU Standard Deviation: {np.std(metrics[:, 0]):.4f}")
print(f"Average F1 Score: {np.mean(metrics[:, 1]):.4f}")
print(f"F1 Score Standard Deviation: {np.std(metrics[:, 1]):.4f}")
print(f"Average Dice Loss: {np.mean(metrics[:, 2]):.4f}")
print(f"Dice Loss Standard Deviation: {np.std(metrics[:, 2]):.4f}")

# Visualization of first three images with masks
plt.figure(figsize=(20, 15))

for i in range(3):
    # Original image
    plt.subplot(3, 3, i*3+1)
    plt.imshow(x_test[i])
    plt.title(f"Original Image {i+1}")
    plt.axis('off')

    # Real mask
    plt.subplot(3, 3, i*3+2)
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    plt.title(f"Real Mask {i+1}")
    plt.axis('off')

    # Predicted mask
    predicted_mask = model.predict(x_test[i][np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    plt.subplot(3, 3, i*3+3)
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.title(f"Predicted Mask {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Metrics Summary:
# Average IoU: 0.4963
# IoU Standard Deviation: 0.0618
# Average F1 Score: 0.6611
# F1 Score Standard Deviation: 0.0562
# Average Dice Loss: 0.3389
# Dice Loss Standard Deviation: 0.0562
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
