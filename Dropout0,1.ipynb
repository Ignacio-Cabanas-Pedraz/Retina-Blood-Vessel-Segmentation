# %%
# !pip install onedrivedownloader
from onedrivedownloader import download

url = 'https://universidadfv-my.sharepoint.com/:u:/g/personal/alberto_desantos_ufv_es/EVwGsj7cAV5EvjJPWcqJ1lUBPhP5mKEkv-6fzmAM4jJSkw?e=pjOhYH'

download(url = url, filename = 'archivo.zip', unzip=True, force_download=True, clean=True)
# Out:
# Collecting onedrivedownloader
#   Downloading onedrivedownloader-1.1.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# Downloading onedrivedownloader-1.1.3-py3-none-any.whl (5.1 kB)
# Installing collected packages: onedrivedownloader
# Successfully installed onedrivedownloader-1.1.3
# 100%|██████████| 34.5M/34.5M [00:03<00:00, 9.40MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 200/200 [00:00<00:00, 392.03it/s]
# ''

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization,Conv2DTranspose,Activation,concatenate,Input
from tensorflow.keras import Sequential,Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
# Definimos la tasa de Dropout
dropout_rate = 0.1  # Empezaremos con un valor bajo, 0.1

# Función de bloque de convolución con Dropout
def conv_block(input, filters, dropout_rate):
    x = Conv2D(filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(dropout_rate)(x)  # Añadimos Dropout

    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(dropout_rate)(x)  # Añadimos Dropout
    return x

# Bloque del encoder con Dropout
def encoder_block(input, filters, dropout_rate):
    x = conv_block(input, filters, dropout_rate)
    p = MaxPooling2D((2, 2))(x)
    return x, p

# Bloque del decoder con Dropout
def decoder_block(input, skip, filters, dropout_rate):
    x = Conv2DTranspose(filters, 2, strides=2, padding="same")(input)
    x = concatenate([x, skip])
    x = conv_block(x, filters, dropout_rate)
    return x

# %%
# Construcción del modelo con Dropout
def build_model(dropout_rate):
    input = Input(shape=(512, 512, 3))

    # Encoder con Dropout
    x1, p1 = encoder_block(input, 64, dropout_rate)
    x2, p2 = encoder_block(p1, 128, dropout_rate)
    x3, p3 = encoder_block(p2, 256, dropout_rate)
    x4, p4 = encoder_block(p3, 512, dropout_rate)

    # Bottleneck
    a1 = conv_block(p4, 1024, dropout_rate)

    # Decoder con Dropout
    d1 = decoder_block(a1, x4, 512, dropout_rate)
    d2 = decoder_block(d1, x3, 256, dropout_rate)
    d3 = decoder_block(d2, x2, 128, dropout_rate)
    d4 = decoder_block(d3, x1, 64, dropout_rate)

    # Salida
    output = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d4)
    model = Model(input, output)
    return model

# %%
def load_data(path,img_size):
    images = []
    masks = []
    for img_files,mask_files in zip(os.listdir(path+"/image"),os.listdir(path+"/mask")):
        img_path = os.path.join(path+"/image",img_files)
        mask_path = os.path.join(path+"/mask",mask_files)

        img = load_img(img_path,target_size=img_size)
        mask = load_img(mask_path,target_size=img_size,color_mode="grayscale")

        img = img_to_array(img)/255.0
        mask = img_to_array(mask)/255.0

        images.append(img)
        masks.append(mask)
    return np.array(images),np.array(masks)

# %%
def augment_image(image, mask):

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, mask

# %%
x_train,y_train = load_data("/content/Data/train",img_size=(512,512))
x_test,y_test = load_data("/content/Data/test",img_size=(512,512))
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((80, 512, 512, 3), (80, 512, 512, 1), (20, 512, 512, 3), (20, 512, 512, 1))

# %%
def tf_dataset(x,y,batch_size=8):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=8)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = tf_dataset(x_train,y_train,batch_size=8)
test_dataset = tf_dataset(x_test,y_test,batch_size=8)

# %%
# Construir el modelo con el primer Dropout Rate (0.1)
model = build_model(dropout_rate)
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min',
                               verbose=1, restore_best_weights=True)

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    batch_size=8,
                    validation_data=test_dataset,
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6042 - loss: 0.6761
# Epoch 1: val_loss improved from inf to 1196.99536, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 179s 5s/step - accuracy: 0.6158 - loss: 0.6643 - val_accuracy: 0.1678 - val_loss: 1196.9954
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8778 - loss: 0.3119
# Epoch 2: val_loss did not improve from 1196.99536
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.8775 - loss: 0.3115 - val_accuracy: 0.0572 - val_loss: 1470.5471
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8794 - loss: 0.2837
# Epoch 3: val_loss did not improve from 1196.99536
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8791 - loss: 0.2841 - val_accuracy: 0.2612 - val_loss: 3837.4031
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8796 - loss: 0.2775
# Epoch 4: val_loss improved from 1196.99536 to 320.29962, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.8793 - loss: 0.2780 - val_accuracy: 0.2666 - val_loss: 320.2996
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8793 - loss: 0.2758
# Epoch 5: val_loss improved from 320.29962 to 7.25341, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8790 - loss: 0.2761 - val_accuracy: 0.7052 - val_loss: 7.2534
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8810 - loss: 0.2698
# Epoch 6: val_loss did not improve from 7.25341
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8806 - loss: 0.2704 - val_accuracy: 0.0791 - val_loss: 13.8033
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8800 - loss: 0.2693
# Epoch 7: val_loss improved from 7.25341 to 1.40646, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8797 - loss: 0.2698 - val_accuracy: 0.5865 - val_loss: 1.4065
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8773 - loss: 0.2701
# Epoch 8: val_loss improved from 1.40646 to 0.63132, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.8772 - loss: 0.2703 - val_accuracy: 0.8770 - val_loss: 0.6313
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8800 - loss: 0.2653
# Epoch 9: val_loss improved from 0.63132 to 0.44666, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.
saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.8792 - loss: 0.2568 - val_accuracy: 0.8770 - val_loss: 0.2881
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8805 - loss: 0.2502
# Epoch 31: val_loss did not improve from 0.28811
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8801 - loss: 0.2506 - val_accuracy: 0.8770 - val_loss: 0.3091
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8811 - loss: 0.2530
# Epoch 32: val_loss did not improve from 0.28811
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8807 - loss: 0.2538 - val_accuracy: 0.8770 - val_loss: 0.3075
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8800 - loss: 0.2551
# Epoch 33: val_loss improved from 0.28811 to 0.27772, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.8797 - loss: 0.2555 - val_accuracy: 0.8770 - val_loss: 0.2777
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8788 - loss: 0.2532
# Epoch 34: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8786 - loss: 0.2536 - val_accuracy: 0.8770 - val_loss: 0.2821
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8803 - loss: 0.2547
# Epoch 35: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8800 - loss: 0.2553 - val_accuracy: 0.8770 - val_loss: 0.2976
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8803 - loss: 0.2514
# Epoch 36: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8800 - loss: 0.2521 - val_accuracy: 0.8770 - val_loss: 0.2969
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8798 - loss: 0.2549
# Epoch 37: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8796 - loss: 0.2556 - val_accuracy: 0.8770 - val_loss: 0.3059
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8798 - loss: 0.2524
# Epoch 38: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8795 - loss: 0.2527 - val_accuracy: 0.8770 - val_loss: 0.3228
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8802 - loss: 0.2565
# Epoch 39: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.8799 - loss: 0.2567 - val_accuracy: 0.8770 - val_loss: 0.3152
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8790 - loss: 0.2498
# Epoch 40: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8788 - loss: 0.2501 - val_accuracy: 0.8770 - val_loss: 0.2825
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8790 - loss: 0.2551
# Epoch 41: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8788 - loss: 0.2551 - val_accuracy: 0.8770 - val_loss: 0.3045
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8806 - loss: 0.2517
# Epoch 42: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8802 - loss: 0.2525 - val_accuracy: 0.8770 - val_loss: 0.2955
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8791 - loss: 0.2545
# Epoch 43: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8789 - loss: 0.2549 - val_accuracy: 0.8770 - val_loss: 0.2985
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8802 - loss: 0.2511
# Epoch 44: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8799 - loss: 0.2513 - val_accuracy: 0.8770 - val_loss: 0.2834
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8803 - loss: 0.2472
# Epoch 45: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8799 - loss: 0.2481 - val_accuracy: 0.8770 - val_loss: 0.2778
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8796 - loss: 0.2477
# Epoch 46: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8794 - loss: 0.2484 - val_accuracy: 0.8770 - val_loss: 0.3442
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8788 - loss: 0.2629
# Epoch 47: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8786 - loss: 0.2631 - val_accuracy: 0.8770 - val_loss: 0.2943
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8786 - loss: 0.2556
# Epoch 48: val_loss did not improve from 0.27772
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8785 - loss: 0.2562 - val_accuracy: 0.8770 - val_loss: 0.3056
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.

# %%
import matplotlib.pyplot as plt

# Graficar la pérdida de entrenamiento y validación
def plot_training_history(history):
    # Extraemos la pérdida de entrenamiento y validación
    training_loss = history.history['loss']
    validation_loss = history.history['val_loss']

    # Crear una figura para la gráfica
    plt.figure(figsize=(10, 6))

    # Graficar la pérdida de entrenamiento
    plt.plot(training_loss, label='Pérdida de Entrenamiento', color='b')
    # Graficar la pérdida de validación
    plt.plot(validation_loss, label='Pérdida de Validación', color='r')

    # Títulos y leyendas
    plt.title('Pérdida de Entrenamiento y Validación')
    plt.xlabel('Épocas')
    plt.ylabel('Pérdida')
    plt.legend()
    plt.grid(True)
    plt.show()

# Llamar a la función para graficar el historial del entrenamiento
plot_training_history(history)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def calculate_metrics(y_true, y_pred, threshold=0.5):
    # Ensure binary targets
    y_true_binary = (y_true > threshold).astype(np.int32)
    y_pred_binary = (y_pred > threshold).astype(np.int32)

    # IoU
    intersection = np.sum(y_true_binary * y_pred_binary)
    union = np.sum(y_true_binary) + np.sum(y_pred_binary) - intersection
    iou = intersection / (union + 1e-6)

    # F1 Score
    y_true_flat = y_true_binary.flatten()
    y_pred_flat = y_pred_binary.flatten()
    f1 = f1_score(y_true_flat, y_pred_flat)

    # Dice Loss
    dice = dice_loss(y_true_binary, y_pred_binary)

    return iou, f1, dice.numpy()

# Analyze all images in x_test
metrics = []

for index in range(len(x_test)):
    # Get image and its corresponding mask
    image = x_test[index]
    mask = y_test[index]

    # Predict mask using the trained model
    predicted_mask = model.predict(image[np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    # Calculate metrics
    iou, f1, dice_loss_value = calculate_metrics(mask, predicted_mask)
    metrics.append((iou, f1, dice_loss_value))

# Convert metrics to numpy array for easier calculations
metrics = np.array(metrics)

# Print metrics statistics
print("Metrics Summary:")
print(f"Average IoU: {np.mean(metrics[:, 0]):.4f}")
print(f"IoU Standard Deviation: {np.std(metrics[:, 0]):.4f}")
print(f"Average F1 Score: {np.mean(metrics[:, 1]):.4f}")
print(f"F1 Score Standard Deviation: {np.std(metrics[:, 1]):.4f}")
print(f"Average Dice Loss: {np.mean(metrics[:, 2]):.4f}")
print(f"Dice Loss Standard Deviation: {np.std(metrics[:, 2]):.4f}")

# Visualization of first three images with masks
plt.figure(figsize=(20, 15))

for i in range(3):
    # Original image
    plt.subplot(3, 3, i*3+1)
    plt.imshow(x_test[i])
    plt.title(f"Original Image {i+1}")
    plt.axis('off')

    # Real mask
    plt.subplot(3, 3, i*3+2)
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    plt.title(f"Real Mask {i+1}")
    plt.axis('off')

    # Predicted mask
    predicted_mask = model.predict(x_test[i][np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    plt.subplot(3, 3, i*3+3)
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.title(f"Predicted Mask {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Metrics Summary:
# Average IoU: 0.1188
# IoU Standard Deviation: 0.1111
# Average F1 Score: 0.1965
# F1 Score Standard Deviation: 0.1614
# Average Dice Loss: 0.8035
# Dice Loss Standard Deviation: 0.1614
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
