# %%
# !pip install onedrivedownloader
from onedrivedownloader import download

url = 'https://universidadfv-my.sharepoint.com/:u:/g/personal/alberto_desantos_ufv_es/EVwGsj7cAV5EvjJPWcqJ1lUBPhP5mKEkv-6fzmAM4jJSkw?e=pjOhYH'

download(url = url, filename = 'archivo.zip', unzip=True, force_download=True, clean=True)
# Out:
# Requirement already satisfied: onedrivedownloader in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# 100%|██████████| 34.5M/34.5M [00:00<00:00, 77.1MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 200/200 [00:00<00:00, 86525.10it/s]
# ''

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization,Conv2DTranspose,Activation,concatenate,Input
from tensorflow.keras import Sequential,Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
def conv_block(input,filters):
    x = Conv2D(filters,3,padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters,3,padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

def encoder_block(input,filters):

    x = conv_block(input,filters)
    p = MaxPooling2D((2,2))(x)
    return x,p

def decoder_block(input,skip,filters):

    x = Conv2DTranspose(filters,2,strides=2,padding="same")(input)
    x = concatenate([x,skip])
    x = conv_block(x,filters)
    return x

# %%
def build_model():
    input = Input(shape=(512,512,3))

    x1,p1 = encoder_block(input,24)
    x2,p2 = encoder_block(p1,128)
    x3,p3 = encoder_block(p2,256)
    x4,p4 = encoder_block(p3,512)

    a1 = conv_block(p4,1024)

    d1 = decoder_block(a1,x4,512)
    d2 = decoder_block(d1,x3,256)
    d3 = decoder_block(d2,x2,128)
    d4 = decoder_block(d3,x1,24)

    output = Conv2D(1,(1,1),padding="same",activation="sigmoid")(d4)
    model = Model(input,output)
    return model

# %%
def load_data(path,img_size):
    images = []
    masks = []
    for img_files,mask_files in zip(os.listdir(path+"/image"),os.listdir(path+"/mask")):
        img_path = os.path.join(path+"/image",img_files)
        mask_path = os.path.join(path+"/mask",mask_files)

        img = load_img(img_path,target_size=img_size)
        mask = load_img(mask_path,target_size=img_size,color_mode="grayscale")

        img = img_to_array(img)/255.0
        mask = img_to_array(mask)/255.0

        images.append(img)
        masks.append(mask)
    return np.array(images),np.array(masks)

# %%
def augment_image(image, mask):

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, mask

# %%
x_train,y_train = load_data("/content/Data/train",img_size=(512,512))
x_test,y_test = load_data("/content/Data/test",img_size=(512,512))
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((80, 512, 512, 3), (80, 512, 512, 1), (20, 512, 512, 3), (20, 512, 512, 1))

# %%
def tf_dataset(x,y,batch_size=8):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=8)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = tf_dataset(x_train,y_train,batch_size=8)
test_dataset = tf_dataset(x_test,y_test,batch_size=8)

# %%
model = build_model()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min',
                               verbose=1, restore_best_weights=True)

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    batch_size=8,
                    validation_data=test_dataset,
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6436 - loss: 0.6172
# Epoch 1: val_loss improved from inf to 23.93670, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 142s 4s/step - accuracy: 0.6541 - loss: 0.6088 - val_accuracy: 0.0573 - val_loss: 23.9367
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8754 - loss: 0.3767
# Epoch 2: val_loss did not improve from 23.93670
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8752 - loss: 0.3760 - val_accuracy: 0.0628 - val_loss: 30.8417
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8788 - loss: 0.3430
# Epoch 3: val_loss did not improve from 23.93670
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8786 - loss: 0.3428 - val_accuracy: 0.0580 - val_loss: 1494.4626
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8785 - loss: 0.3257
# Epoch 4: val_loss did not improve from 23.93670
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8783 - loss: 0.3256 - val_accuracy: 0.0624 - val_loss: 440.6781
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8783 - loss: 0.3254
# Epoch 5: val_loss improved from 23.93670 to 18.07253, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8781 - loss: 0.3251 - val_accuracy: 0.0769 - val_loss: 18.0725
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8790 - loss: 0.3087
# Epoch 6: val_loss improved from 18.07253 to 1.02217, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8788 - loss: 0.3087 - val_accuracy: 0.1184 - val_loss: 1.0222
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8782 - loss: 0.3003
# Epoch 7: val_loss improved from 1.02217 to 0.52889, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8781 - loss: 0.3003 - val_accuracy: 0.7697 - val_loss: 0.5289
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8793 - loss: 0.2919
# Epoch 8: val_loss improved from 0.52889 to 0.49793, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8790 - loss: 0.2919 - val_accuracy: 0.7786 - val_loss: 0.4979
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8795 - loss: 0.2860
# Epoch 9: val_loss did not improve from 0.49793
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8792 - loss: 0.2862 - val_accuracy: 0.6782 - val_loss: 0.5694
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8778 - loss: 0.2835
# Epoch 10: val_loss did not improve from 0.49793
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8778 - loss: 0.2836 - val_accuracy: 0.7034 - val_loss: 0.5515
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8790 - loss: 0.2757
# Epoch 11: val_loss improved from 0.49793 to 0.46800, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8788 - loss: 0.2764 - val_accuracy: 0.8091 - val_loss: 0.4680
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8785 - loss: 0.2730
# Epoch 12: val_loss improved from 0.46800 to 0.35269, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8784 - loss: 0.2732 - val_accuracy: 0.8770 - val_loss: 0.3527
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8797 - loss: 0.2696
# Epoch 13: val_loss did not improve from 0.35269
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8794 - loss: 0.2699 - val_accuracy: 0.8770 - val_loss: 0.3552
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8791 - loss: 0.2778
# Epoch 14: val_loss improved from 0.35269 to 0.33276, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8789 - loss: 0.2777 - val_accuracy: 0.8770 - val_loss: 0.3328
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8781 - loss: 0.2688
# Epoch 15: val_loss did not improve from 0.33276
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8780 - loss: 0.2690 - val_accuracy: 0.8770 - val_loss: 0.3433
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8779 - loss: 0.2745
# Epoch 16: val_loss improved from 0.33276 to 0.32457, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8778 - loss: 0.2743 - val_accuracy: 0.8770 - val_loss: 0.3246
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8794 - loss: 0.2637
# Epoch 17: val_loss did not improve from 0.32457
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8792 - loss: 0.2637 - val_accuracy: 0.8770 - val_loss: 0.3280
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8791 - loss: 0.2641
# Epoch 18: val_loss improved from 0.32457 to 0.31979, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.8789 - loss: 0.2643 - val_accuracy: 0.8770 - val_loss: 0.3198
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8783 - loss: 0.2627
# Epoch 19: val_loss improved from 0.31979 to 0.31761, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8781 - loss: 0.2630 - val_accuracy: 0.8770 - val_loss: 0.3176
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8792 - loss: 0.2574
# Epoch 20: val_loss did not improve from 0.31761
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8789 - loss: 0.2579 - val_accuracy: 0.8770 - val_loss: 0.3185
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8790 - loss: 0.2588
# Epoch 21: val_loss did not improve from 0.31761
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8788 - loss: 0.2591 - val_accuracy: 0.8770 - val_loss: 0.3435
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8789 - loss: 0.2621
# Epoch 22: val_loss did not improve from 0.31761
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8787 - loss: 0.2622 - val_accuracy: 0.8770 - val_loss: 0.3382
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8788 - loss: 0.2627
# Epoch 23: val_loss improved from 0.31761 to 0.31151, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.8787 - loss: 0.2628 - val_accuracy: 0.8770 - val_loss: 0.3115
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8795 - loss: 0.2561
# Epoch 24: val_loss did not improve from 0.31151
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.8793 - loss: 0.2562 - val_accuracy: 0.8770 - val_loss: 0.3354
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8785 - loss: 0.2526
# Epoch 25: val_loss did not improve from 0.31151
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8783 - loss: 0.2530 - val_accuracy: 0.8770 - val_loss: 0.3349
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8791 - loss: 0.2549
# Epoch 26: val_loss did not improve from 0.31151
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8789 - loss: 0.2551 - val_accuracy: 0.8770 - val_loss: 0.3385
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8776 - loss: 0.2634
# Epoch 27: val_loss did not improve from 0.31151
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8775 - loss: 0.2631 - val_accuracy: 0.8770 - val_loss: 0.3279
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8797 - loss: 0.2508
# Epoch 28: val_loss did not improve from 0.31151
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8795 - loss: 0.2515 - val_accuracy: 0.8770 - val_loss: 0.3330
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8781 - loss: 0.2612
# Epoch 29: val_loss did not improve from 0.31151
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8780 - loss: 0.2612 - val_accuracy: 0.8770 - val_loss: 0.3154
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8797 - loss: 0.2586
# Epoch 30: val_loss improved from 0.31151 to 0.30044, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8795 - loss: 0.2588 - val_accuracy: 0.8770 - val_loss: 0.3004
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8790 - loss: 0.2583
# Epoch 31: val_loss improved from 0.30044 to 0.29809, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8788 - loss: 0.2585 - val_accuracy: 0.8770 - val_loss: 0.2981
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8780 - loss: 0.2653
# Epoch 32: val_loss did not improve from 0.29809
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8779 - loss: 0.2651 - val_accuracy: 0.8770 - val_loss: 0.3016
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8784 - loss: 0.2529
# Epoch 33: val_loss improved from 0.29809 to 0.28997, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - accuracy: 0.8783 - loss: 0.2532 - val_accuracy: 0.8770 - val_loss: 0.2900
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8792 - loss: 0.2542
# Epoch 34: val_loss improved from 0.28997 to 0.28501, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8790 - loss: 0.2544 - val_accuracy: 0.8770 - val_loss: 0.2850
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8792 - loss: 0.2565
# Epoch 35: val_loss did not improve from 0.28501
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8790 - loss: 0.2565 - val_accuracy: 0.8770 - val_loss: 0.2913
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8785 - loss: 0.2591
# Epoch 36: val_loss did not improve from 0.28501
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8783 - loss: 0.2591 - val_accuracy: 0.8770 - val_loss: 0.2958
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8796 - loss: 0.2515
# Epoch 37: val_loss did not improve from 0.28501
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8794 - loss: 0.2520 - val_accuracy: 0.8770 - val_loss: 0.2920
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8792 - loss: 0.2516
# Epoch 38: val_loss improved from 0.28501 to 0.28073, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8790 - loss: 0.2522 - val_accuracy: 0.8770 - val_loss: 0.2807
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8786 - loss: 0.2461
# Epoch 39: val_loss improved from 0.28073 to 0.26401, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.8784 - loss: 0.2465 - val_accuracy: 0.8770 - val_loss: 0.2640
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8782 - loss: 0.2454
# Epoch 40: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8781 - loss: 0.2455 - val_accuracy: 0.8770 - val_loss: 0.2758
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8784 - loss: 0.2543
# Epoch 41: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8782 - loss: 0.2543 - val_accuracy: 0.8770 - val_loss: 0.2673
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8788 - loss: 0.2503
# Epoch 42: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8787 - loss: 0.2509 - val_accuracy: 0.8770 - val_loss: 0.2708
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8782 - loss: 0.2576
# Epoch 43: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8781 - loss: 0.2576 - val_accuracy: 0.8770 - val_loss: 0.3131
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8793 - loss: 0.2494
# Epoch 44: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8790 - loss: 0.2497 - val_accuracy: 0.8770 - val_loss: 0.2802
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8794 - loss: 0.2517
# Epoch 45: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.8792 - loss: 0.2522 - val_accuracy: 0.8770 - val_loss: 0.2828
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8787 - loss: 0.2494
# Epoch 46: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8785 - loss: 0.2498 - val_accuracy: 0.8770 - val_loss: 0.2835
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8785 - loss: 0.2548
# Epoch 47: val_loss did not improve from 0.26401
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8783 - loss: 0.2549 - val_accuracy: 0.8770 - val_loss: 0.2971
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8789 - loss: 0.2500
# Epoch 48: val_loss improved from 0.26401 to 0.26377, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 25s 3s/step - accuracy: 0.8787 - loss: 0.2502 - val_accuracy: 0.8770 - val_loss: 0.2638
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8792 - loss: 0.2454
# Epoch 49: val_loss did not improve from 0.26377
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8789 - loss: 0.2458 - val_accuracy: 0.8770 - val_loss: 0.2681
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8791 - loss: 0.2528
# Epoch 50: val_loss improved from 0.26377 to 0.25280, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - accuracy: 0.8789 - loss: 0.2527 - val_accuracy: 0.8770 - val_loss: 0.2528
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8802 - loss: 0.2477
# Epoch 51: val_loss improved from 0.25280 to 0.25093, saving model to best_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8799 - loss: 0.2480 - val_accuracy: 0.8770 - val_loss: 0.2509
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8801 - loss: 0.2468
# Epoch 52: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8798 - loss: 0.2474 - val_accuracy: 0.8770 - val_loss: 0.2550
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8783 - loss: 0.2550
# Epoch 53: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8781 - loss: 0.2553 - val_accuracy: 0.8770 - val_loss: 0.2636
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8795 - loss: 0.2535
# Epoch 54: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8793 - loss: 0.2533 - val_accuracy: 0.8770 - val_loss: 0.2624
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8794 - loss: 0.2579
# Epoch 55: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8792 - loss: 0.2582 - val_accuracy: 0.8770 - val_loss: 0.2612
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8799 - loss: 0.2469
# Epoch 56: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8796 - loss: 0.2472 - val_accuracy: 0.8770 - val_loss: 0.2594
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8791 - loss: 0.2537
# Epoch 57: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8789 - loss: 0.2539 - val_accuracy: 0.8770 - val_loss: 0.2636
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8786 - loss: 0.2482
# Epoch 58: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8785 - loss: 0.2483 - val_accuracy: 0.8770 - val_loss: 0.2573
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8788 - loss: 0.2483
# Epoch 59: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.8786 - loss: 0.2488 - val_accuracy: 0.8770 - val_loss: 0.2818
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8785 - loss: 0.2510
# Epoch 60: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8783 - loss: 0.2510 - val_accuracy: 0.8770 - val_loss: 0.2583
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8774 - loss: 0.2533
# Epoch 61: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8774 - loss: 0.2533 - val_accuracy: 0.8770 - val_loss: 0.2604
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8794 - loss: 0.2424
# Epoch 62: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8791 - loss: 0.2426 - val_accuracy: 0.8770 - val_loss: 0.2595
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8797 - loss: 0.2414
# Epoch 63: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8794 - loss: 0.2422 - val_accuracy: 0.8770 - val_loss: 0.2548
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8798 - loss: 0.2457
# Epoch 64: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8795 - loss: 0.2463 - val_accuracy: 0.8770 - val_loss: 0.2601
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8789 - loss: 0.2504
# Epoch 65: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8787 - loss: 0.2506 - val_accuracy: 0.8770 - val_loss: 0.2633
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8773 - loss: 0.2519
# Epoch 66: val_loss did not improve from 0.25093
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.8772 - loss: 0.2519 - val_accuracy: 0.8770 - val_loss: 0.2633
# Epoch 66: early stopping
# Restoring model weights from the end of the best epoch: 51.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def calculate_metrics(y_true, y_pred, threshold=0.5):
    # Ensure binary targets
    y_true_binary = (y_true > threshold).astype(np.int32)
    y_pred_binary = (y_pred > threshold).astype(np.int32)

    # IoU
    intersection = np.sum(y_true_binary * y_pred_binary)
    union = np.sum(y_true_binary) + np.sum(y_pred_binary) - intersection
    iou = intersection / (union + 1e-6)

    # F1 Score
    y_true_flat = y_true_binary.flatten()
    y_pred_flat = y_pred_binary.flatten()
    f1 = f1_score(y_true_flat, y_pred_flat)

    # Dice Loss
    dice = dice_loss(y_true_binary, y_pred_binary)

    return iou, f1, dice.numpy()

# Analyze all images in x_test
metrics = []

for index in range(len(x_test)):
    # Get image and its corresponding mask
    image = x_test[index]
    mask = y_test[index]

    # Predict mask using the trained model
    predicted_mask = model.predict(image[np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    # Calculate metrics
    iou, f1, dice_loss_value = calculate_metrics(mask, predicted_mask)
    metrics.append((iou, f1, dice_loss_value))

# Convert metrics to numpy array for easier calculations
metrics = np.array(metrics)

# Print metrics statistics
print("Metrics Summary:")
print(f"Average IoU: {np.mean(metrics[:, 0]):.4f}")
print(f"IoU Standard Deviation: {np.std(metrics[:, 0]):.4f}")
print(f"Average F1 Score: {np.mean(metrics[:, 1]):.4f}")
print(f"F1 Score Standard Deviation: {np.std(metrics[:, 1]):.4f}")
print(f"Average Dice Loss: {np.mean(metrics[:, 2]):.4f}")
print(f"Dice Loss Standard Deviation: {np.std(metrics[:, 2]):.4f}")

# Visualization of first three images with masks
plt.figure(figsize=(20, 15))

for i in range(3):
    # Original image
    plt.subplot(3, 3, i*3+1)
    plt.imshow(x_test[i])
    plt.title(f"Original Image {i+1}")
    plt.axis('off')

    # Real mask
    plt.subplot(3, 3, i*3+2)
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    plt.title(f"Real Mask {i+1}")
    plt.axis('off')

    # Predicted mask
    predicted_mask = model.predict(x_test[i][np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    plt.subplot(3, 3, i*3+3)
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.title(f"Predicted Mask {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Metrics Summary:
# Average IoU: 0.3102
# IoU Standard Deviation: 0.1148
# Average F1 Score: 0.4613
# F1 Score Standard Deviation: 0.1402
# Average Dice Loss: 0.5387
# Dice Loss Standard Deviation: 0.1402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
