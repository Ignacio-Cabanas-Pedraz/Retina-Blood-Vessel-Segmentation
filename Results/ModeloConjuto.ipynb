# %%
# !pip install onedrivedownloader
from onedrivedownloader import download

url = 'https://universidadfv-my.sharepoint.com/:u:/g/personal/alberto_desantos_ufv_es/EVwGsj7cAV5EvjJPWcqJ1lUBPhP5mKEkv-6fzmAM4jJSkw?e=pjOhYH'

download(url = url, filename = 'archivo.zip', unzip=True, force_download=True, clean=True)
# Out:
# Collecting onedrivedownloader
#   Downloading onedrivedownloader-1.1.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from onedrivedownloader) (4.66.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->onedrivedownloader) (2024.8.30)
# Downloading onedrivedownloader-1.1.3-py3-none-any.whl (5.1 kB)
# Installing collected packages: onedrivedownloader
# Successfully installed onedrivedownloader-1.1.3
# 100%|██████████| 34.5M/34.5M [00:03<00:00, 9.21MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 200/200 [00:01<00:00, 183.69it/s]
# ''

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, BatchNormalization,Conv2DTranspose,Activation,concatenate,Input
from tensorflow.keras import Sequential,Model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.layers import LeakyReLU

def conv_block(input,filters):
    x = Conv2D(filters,3,padding="same")(input)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)

    x = Conv2D(filters,3,padding="same")(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
    return x

def encoder_block(input,filters):

    x = conv_block(input,filters)
    p = MaxPooling2D((2,2))(x)
    return x,p

def decoder_block(input,skip,filters):

    x = Conv2DTranspose(filters,2,strides=2,padding="same")(input)
    x = concatenate([x,skip])
    x = conv_block(x,filters)
    return x

# %%
def build_model():
    # Entrada del modelo
    input = Input(shape=(512, 512, 3))

    # Encoder con 2 capas
    x1, p1 = encoder_block(input, 16)   # Primer bloque del encoder, tamaño 16
    x2, p2 = encoder_block(p1, 128)     # Segundo bloque del encoder

    # Bottleneck (parte intermedia)
    a1 = conv_block(p2, 256)

    # Decoder con 2 capas
    d1 = decoder_block(a1, x2, 128)     # Primer bloque del decoder
    d2 = decoder_block(d1, x1, 16)      # Segundo boque del decoder, tamaño 16

    # Capa de salida
    output = Conv2D(1, (1, 1), padding="same", activation="sigmoid")(d2)

    # Definir el modelo
    model = Model(input, output)
    return model

# %%
def load_data(path,img_size):
    images = []
    masks = []
    for img_files,mask_files in zip(os.listdir(path+"/image"),os.listdir(path+"/mask")):
        img_path = os.path.join(path+"/image",img_files)
        mask_path = os.path.join(path+"/mask",mask_files)

        img = load_img(img_path,target_size=img_size)
        mask = load_img(mask_path,target_size=img_size,color_mode="grayscale")

        img = img_to_array(img)/255.0
        mask = img_to_array(mask)/255.0

        images.append(img)
        masks.append(mask)
    return np.array(images),np.array(masks)

# %%
def augment_image(image, mask):

    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.1)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
    return image, mask

# %%
x_train,y_train = load_data("/content/Data/train",img_size=(512,512))
x_test,y_test = load_data("/content/Data/test",img_size=(512,512))
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((80, 512, 512, 3), (80, 512, 512, 1), (20, 512, 512, 3), (20, 512, 512, 1))

# %%
def tf_dataset(x,y,batch_size=6):
    dataset = tf.data.Dataset.from_tensor_slices((x,y))
    dataset = dataset.shuffle(buffer_size=8)
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(augment_image, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

train_dataset = tf_dataset(x_train,y_train,batch_size=6)
test_dataset = tf_dataset(x_test,y_test,batch_size=6)

# %%
model = build_model()
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)

early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min',
                               verbose=1, restore_best_weights=True)

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    batch_size=6,
                    validation_data=test_dataset,
                    callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5563 - loss: 0.7102
# Epoch 1: val_loss improved from inf to 0.67138, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.5633 - loss: 0.7053 - val_accuracy: 0.8638 - val_loss: 0.6714
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8643 - loss: 0.4820
# Epoch 2: val_loss did not improve from 0.67138
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 473ms/step - accuracy: 0.8645 - loss: 0.4810 - val_accuracy: 0.7543 - val_loss: 0.6723
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8767 - loss: 0.4241
# Epoch 3: val_loss improved from 0.67138 to 0.60622, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 498ms/step - accuracy: 0.8766 - loss: 0.4236 - val_accuracy: 0.8766 - val_loss: 0.6062
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8771 - loss: 0.3920
# Epoch 4: val_loss improved from 0.60622 to 0.56343, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 497ms/step - accuracy: 0.8771 - loss: 0.3917 - val_accuracy: 0.8769 - val_loss: 0.5634
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.8776 - loss: 0.3697
# Epoch 5: val_loss improved from 0.56343 to 0.53295, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 572ms/step - accuracy: 0.8776 - loss: 0.3694 - val_accuracy: 0.8770 - val_loss: 0.5330
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8801 - loss: 0.3510
# Epoch 6: val_loss improved from 0.53295 to 0.50767, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 511ms/step - accuracy: 0.8799 - loss: 0.3510 - val_accuracy: 0.8770 - val_loss: 0.5077
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.8795 - loss: 0.3366
# Epoch 7: val_loss improved from 0.50767 to 0.47203, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 508ms/step - accuracy: 0.8793 - loss: 0.3366 - val_accuracy: 0.8770 - val_loss: 0.4720
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.8795 - loss: 0.3233
# Epoch 8: val_loss improved from 0.47203 to 0.42909, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 565ms/step - accuracy: 0.8793 - loss: 0.3234 - val_accuracy: 0.8770 - val_loss: 0.4291
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8785 - loss: 0.3141
# Epoch 9: val_loss improved from 0.42909 to 0.39344, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 514ms/step - accuracy: 0.8784 - loss: 0.3141 - val_accuracy: 0.8770 - val_loss: 0.3934
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8784 - loss: 0.3095
# Epoch 10: val_loss improved from 0.39344 to 0.38912, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 509ms/step - accuracy: 0.8783 - loss: 0.3094 - val_accuracy: 0.8770 - val_loss: 0.3891
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.8798 - loss: 0.2993
# Epoch 11: val_loss improved from 0.38912 to 0.36353, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 513ms/step - accuracy: 0.8796 - loss: 0.2995 - val_accuracy: 0.8770 - val_loss: 0.3635
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - accuracy: 0.8789 - loss: 0.2942
# Epoch 12: val_loss improved from 0.36353 to 0.34497, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 518ms/step - accuracy: 0.8788 - loss: 0.2942 - val_accuracy: 0.8770 - val_loss: 0.3450
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.8797 - loss: 0.2872
# Epoch 13: val_loss improved from 0.34497 to 0.33722, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 568ms/step - accuracy: 0.8795 - loss: 0.2873 - val_accuracy: 0.8770 - val_loss: 0.3372
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.8790 - loss: 0.2824
# Epoch 14: val_loss improved from 0.33722 to 0.33006, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 521ms/step - accuracy: 0.8789 - loss: 0.2825 - val_accuracy: 0.8770 - val_loss: 0.3301
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.8784 - loss: 0.2799
# Epoch 15: val_loss improved from 0.33006 to 0.32207, saving model to best_model.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.8786 - loss: 0.2585
# Epoch 72: val_loss did not improve from 0.24338
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10s 501ms/step - accuracy: 0.8785 - loss: 0.2587 - val_accuracy: 0.8770 - val_loss: 0.2597
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8777 - loss: 0.2516
# Epoch 73: val_loss did not improve from 0.24338
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 548ms/step - accuracy: 0.8776 - loss: 0.2517 - val_accuracy: 0.8770 - val_loss: 0.2604
# Epoch 73: early stopping
# Restoring model weights from the end of the best epoch: 58.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2.0 * intersection + smooth) / (union + smooth)
    return 1 - dice

def calculate_metrics(y_true, y_pred, threshold=0.5):
    # Ensure binary targets
    y_true_binary = (y_true > threshold).astype(np.int32)
    y_pred_binary = (y_pred > threshold).astype(np.int32)

    # IoU
    intersection = np.sum(y_true_binary * y_pred_binary)
    union = np.sum(y_true_binary) + np.sum(y_pred_binary) - intersection
    iou = intersection / (union + 1e-6)

    # F1 Score
    y_true_flat = y_true_binary.flatten()
    y_pred_flat = y_pred_binary.flatten()
    f1 = f1_score(y_true_flat, y_pred_flat)

    # Dice Loss
    dice = dice_loss(y_true_binary, y_pred_binary)

    return iou, f1, dice.numpy()

# Analyze all images in x_test
metrics = []

for index in range(len(x_test)):
    # Get image and its corresponding mask
    image = x_test[index]
    mask = y_test[index]

    # Predict mask using the trained model
    predicted_mask = model.predict(image[np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    # Calculate metrics
    iou, f1, dice_loss_value = calculate_metrics(mask, predicted_mask)
    metrics.append((iou, f1, dice_loss_value))

# Convert metrics to numpy array for easier calculations
metrics = np.array(metrics)

# Print metrics statistics
print("Metrics Summary:")
print(f"Average IoU: {np.mean(metrics[:, 0]):.4f}")
print(f"IoU Standard Deviation: {np.std(metrics[:, 0]):.4f}")
print(f"Average F1 Score: {np.mean(metrics[:, 1]):.4f}")
print(f"F1 Score Standard Deviation: {np.std(metrics[:, 1]):.4f}")
print(f"Average Dice Loss: {np.mean(metrics[:, 2]):.4f}")
print(f"Dice Loss Standard Deviation: {np.std(metrics[:, 2]):.4f}")

# Visualization of first three images with masks
plt.figure(figsize=(20, 15))

for i in range(3):
    # Original image
    plt.subplot(3, 3, i*3+1)
    plt.imshow(x_test[i])
    plt.title(f"Original Image {i+1}")
    plt.axis('off')

    # Real mask
    plt.subplot(3, 3, i*3+2)
    plt.imshow(y_test[i].squeeze(), cmap='gray')
    plt.title(f"Real Mask {i+1}")
    plt.axis('off')

    # Predicted mask
    predicted_mask = model.predict(x_test[i][np.newaxis, ...])[0]
    predicted_mask = (predicted_mask > 0.2).astype(np.float32)

    plt.subplot(3, 3, i*3+3)
    plt.imshow(predicted_mask.squeeze(), cmap='gray')
    plt.title(f"Predicted Mask {i+1}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Metrics Summary:
# Average IoU: 0.4319
# IoU Standard Deviation: 0.0907
# Average F1 Score: 0.5976
# F1 Score Standard Deviation: 0.0902
# Average Dice Loss: 0.4024
# Dice Loss Standard Deviation: 0.0902
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
